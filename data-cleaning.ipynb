# %%
import pandas as pd
import pathlib as path

# %%
#read csv files 
file1 ="box_office_all_time.csv"
file2 ="box_office.csv"

box_office_all_time_df = pd.read_csv(file1)
box_office_all_time_df

box_office_df = pd.read_csv(file2)
box_office_df
# Out:
#             id  rank                                       title  \
# 0    tt0499549     1                                      Avatar
# 1    tt4154796     2                           Avengers: Endgame
# 2    tt1630029     3                    Avatar: The Way of Water
# 3    tt0120338     4                                     Titanic
# 4    tt2488496     5  Star Wars: Episode VII - The Force Awakens
# ..         ...   ...                                         ...
# 195  tt5971474   196                          The Little Mermaid
# 196  tt1216475   197                                      Cars 2
# 197  tt0360717   198                                   King Kong
# 198  tt0448694   199                               Puss in Boots
# 199  tt4701660   200                                 The Mermaid
#
#     worldwideLifetimeGross domesticLifetimeGross domestic  \
# 0           $2,923,706,026          $785,221,649    26.9%
# 1           $2,799,439,100          $858,373,000    30.7%
# ...

# %%
#combined the 2 dataframes
combined_df = pd.merge(box_office_all_time_df,box_office_df, on="id")
combined_df.head(20)
# Out:
#             id  rank_x                                       title_x  \
# 0    tt0499549       1                                        Avatar
# 1    tt4154796       2                             Avengers: Endgame
# 2    tt1630029       3                      Avatar: The Way of Water
# 3    tt0120338       4                                       Titanic
# 4    tt2488496       5    Star Wars: Episode VII - The Force Awakens
# 5    tt4154756       6                        Avengers: Infinity War
# 6   tt10872600       7                       Spider-Man: No Way Home
# 7    tt0369610       8                                Jurassic World
# 8    tt6105098       9                                 The Lion King
# 9    tt0848228      10                                  The Avengers
# 10   tt2820852      11                                     Furious 7
# 11   tt1745960      12                             Top Gun: Maverick
# 12   tt4520988      13                                     Frozen II
# ...

# %%
# export datafram to csv files 
combined_df.to_csv ('combined_box_office.csv', index=False)
