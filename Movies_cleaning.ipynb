# %%
import pandas as pd 
import pathlib as path

# %%
data = pd.read_csv('combined_top10.csv')
data
# Out:
#           id                                       title     originalTitle  \
# 0  tt0499549                                      Avatar               NaN
# 1  tt4154796                           Avengers: Endgame               NaN
# 2  tt0120338                                     Titanic               NaN
# 3  tt2488496  Star Wars: Episode VII - The Force Awakens               NaN
# 4  tt4154756                      Avengers: Infinity War               NaN
# 5  tt0369610                              Jurassic World               NaN
# 6  tt0848228                                The Avengers               NaN
# 7  tt0848228                                The Avengers               NaN
# 8  tt2820852                                   Furious 7  Fast & Furious 7
# 9  tt4520988                                   Frozen II               NaN
#
#                                            fullTitle   type  year  \
# 0                                      Avatar (2009)  Movie  2009
# ...
