# %%
import requests
import json
import csv

def json_to_csv(json_data, csv_filename):
    if not json_data:
        print("No JSON data to convert.")
        return

    try:
        with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            
            # Assuming the 'items' key in the JSON contains the list of records.
            records = json_data.get('items', [])
            
            # Write header row with keys as column names.
            if records:
                header = records[0].keys()
                writer.writerow(header)

                for row in records:
                    writer.writerow(row.values())
            else:
                print("No records found in JSON data.")
        
        print(f"Data converted and saved successfully to {csv_filename}")
    except Exception as e:
        print(f"Error converting and saving data to CSV: {e}")

if __name__ == "__main__":
    url = 'https://imdb-api.com/en/API/BoxOfficeAllTime/k_ubtu0kka'
    response = requests.get(url)
    data = json.loads(response.content)

    # Remove all null values from the data
    data = {key: value for key, value in data.items() if value is not None}

    # Convert JSON data to CSV
    csv_filename = "box_office_all_time.csv"
    json_to_csv(data, csv_filename)

# %%
import requests
import json
import csv

def json_to_csv(json_data, csv_filename):
    if not json_data:
        print("No JSON data to convert.")
        return

    try:
        with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            
            # Assuming the 'items' key in the JSON contains the list of records.
            records = json_data.get('items', [])
            
            # Write header row with keys as column names.
            if records:
                header = records[0].keys()
                writer.writerow(header)

                for row in records:
                    writer.writerow(row.values())
            else:
                print("No records found in JSON data.")
        
        print(f"Data converted and saved successfully to {csv_filename}")
    except Exception as e:
        print(f"Error converting and saving data to CSV: {e}")

if __name__ == "__main__":
    url = 'https://imdb-api.com/en/API/BoxOfficeAllTime/k_ubtu0kka'
    response = requests.get(url)
    data = json.loads(response.content)

    # Remove all null values from the data
    data = {key: value for key, value in data.items() if value is not None}

    # Convert JSON data to CSV
    csv_filename = "box_office.csv"
    json_to_csv(data, csv_filename)

# %%
import requests
import json
import csv

def json_to_csv(json_data, csv_filename):
    if not json_data:
        print("No JSON data to convert.")
        return

    try:
        with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            
            # Write header row with keys as column names.
            header = json_data.keys()
            writer.writerow(header)

            # Write the single record (data) as a row in the CSV file.
            writer.writerow(json_data.values())
        
        print(f"Data converted and saved successfully to {csv_filename}")
    except Exception as e:
        print(f"Error converting and saving data to CSV: {e}")

if __name__ == "__main__":
    url = 'https://imdb-api.com/API/AdvancedSearch/k_ubtu0kka?release_date=1977-01-01,2020-01-01&count=250&sort=boxoffice_gross_us,asc'
    response = requests.get(url)
    data = json.loads(response.content)

    # Remove all null values from the data
    data = {key: value for key, value in data.items() if value is not None}

    # Convert JSON data to CSV
    csv_filename = "Movies.csv"
    json_to_csv(data, csv_filename)
# Out:
# Data converted and saved successfully to Movies.csv

# %%
import requests
import json
import csv

def json_to_csv(json_data, csv_filename):
    if not json_data:
        print("No JSON data to convert.")
        return

    try:
        with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            
            # Write header row with keys as column names.
            header = json_data.keys()
            writer.writerow(header)

            # Write the single record (data) as a row in the CSV file.
            writer.writerow(json_data.values())
        
        print(f"Data converted and saved successfully to {csv_filename}")
    except Exception as e:
        print(f"Error converting and saving data to CSV: {e}")

if __name__ == "__main__":
    url = 'https://imdb-api.com/en/API/Title/k_ubtu0kka/tt4520988/Images,Ratings,'
    response = requests.get(url)
    data = json.loads(response.content)

    # Remove all null values from the data
    data = {key: value for key, value in data.items() if value is not None}

    # Convert JSON data to CSV
    csv_filename = "movie10.csv"
    json_to_csv(data, csv_filename)
# Out:
# Data converted and saved successfully to movie10.csv
